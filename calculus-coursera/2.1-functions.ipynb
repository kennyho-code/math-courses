# %% [markdown]
# ### difference quotient
# f(x + h)  - f(x) / h
#
# ### vertical line test
# A test to determine if a relation is a function. If a vertical line passes through a graph and touches the graph at only one point, the relation is a function.
#
# ### piece wise function
# like a switch statement, get the condition, use the function it's paired with
#
# ### even functions
# - y-axis symmetry
#
# ### odd functions
# - origin symmetry
#
# ### increasing and decreasing
#
# ### Reading
# - function
# - independent variables
# - dependent variables
# - modeling functions
# - linear function
# - slope
#     - (f(x2) - (fx1)) / (x2 - x1)
#     - rise/run
#     - y/x
# - parallel lines
#     - same slope
# - perpendicular lines
#     - (- 1/m)
# - slope intercept form
#     - y = mx + b
# - point-slipe form
#     - y - yo = m(x - xo)
#
# ### composition
# -  f(g(x))

# %%
from sympy.plotting import *
from sympy import Symbol

# %%
x = Symbol("x")
plot(x**2)
# Out:
#     100 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#      50 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            \                             /
#         |             ..                         ..
#         |               \                       /
#         |                ..                   ..
# ...

# %%
plot(x**2, (x, -3, 3))
# Out:
#       9 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#     4.5 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            \                             /
#         |             ..                         ..
#         |               \                       /
#         |                ..                   ..
# ...

# %%
plot1 = plot(x**2, (x, -3, 3))
plot1[0].line_color='r'
# Out:
#       9 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#     4.5 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            \                             /
#         |             ..                         ..
#         |               \                       /
#         |                ..                   ..
# ...

# %%
plot1.show()
# Out:
#       9 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#     4.5 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            \                             /
#         |             ..                         ..
#         |               \                       /
#         |                ..                   ..
# ...

# %%
f1 = 3*x + 2 
f2 = x**3
plot(f1, f2)

# %%
plot((f1, (x, -10, 0)), (f2, (x, 0, 10)))

# %%
# quadratic equation calculator
from numpy import sqrt
from sympy.plotting import *
from sympy import Symbol

# %%
x = Symbol('x')

# %%
def zeros(a, b, c):
    D = sqrt(b*b - 4*a*c)
    x1 = (-b + D)/(2*a)
    x2 = (-b - D)/(2*a)
    print("First root is: ", x1)
    print("Second root is: ", x2)

# %%
zeros(1,2,1)
# Out:
# First root is:  -1.0
# Second root is:  -1.0

# %%
def print_graph(a, b, c):
    x = Symbol('x')
    plot(a*x**2 + b*x + c)
print_graph(1, 2, 1)

# %%
def linear(a, b, c, d):
    x = Symbol('x')
    m = (d - b) / (c - a)
    return m*(x - a) + b

# %%
linear(1, -4, 3, 6)
# Out:
# 5.0*x - 9.0

# %%
plot((-4/5) * x + 7)

# %%
f1 = lambda x: 1.25*x - 7.25
f2 = lambda x: 0.8*x - 3.2
f3 = lambda x: 1.25*x + 4
f4 = lambda x: 0.8*x + 5.8

f1(4) == 9
f1(1.5) == 7
# Out:
# False

# %%
f2(4) == 9
f2(1.5) == 7
# Out:
# False

# %%
f3(4) == 9
f3(1.5) == 7
# Out:
# False

# %%
f4(4) == 9
f4(1.5) == 7
# Out:
# True
